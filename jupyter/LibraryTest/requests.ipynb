# %% [markdown]
# # Setup Environment

# %% [markdown]
# !pip install ipykernel

# %%
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 24.1.2 is available.
# You should consider upgrading via the 'd:\pypjts\icrawler\.env64\scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # 패키지/모듈 로딩

# %%
import requests
requests
# Out:
# <module 'requests' from 'd:\\pypjts\\iCrawler\\.env64\\lib\\site-packages\\requests\\__init__.py'>

# %%
url = "https://youtube.com/watch?v=N7mOt3S9VYQ"
r = requests.get(url, stream=True)

for line in r.iter_lines():

    # filter out keep-alive new lines
    if line:
        print()
        print(line)
        # decoded_line = line.decode('utf-8')
        # print(decoded_line.strip())
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="ko-KR" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="BQjpPoigIKgbV6sJTuD38A">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false,"641353869":false,"644029907":false,"1822726157":false}};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="BQjpPoigIKgbV6sJTuD38A">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytc
# ...

# %%
import requests 

def download_file(url, local_filename):
    # Send a GET request to the URL
    with requests.get(url, stream=True) as response:
        response.raise_for_status()  # Check for HTTP request errors
        # Open a local file with write-binary mode
        with open(local_filename, 'wb') as file:
            # Write the content of the response in chunks
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
    print(f"File downloaded: {local_filename}")

url = "https://www.youtube.com/watch?v=tPC97Fi5bNQ&ab_channel=KlauyRos
"
download_file(url, local_filename='test.mp4')
# Out:
# File downloaded: test.mp4
